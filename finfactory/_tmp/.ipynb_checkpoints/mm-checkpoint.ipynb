# %%
from dramkit import plot_series
from finfactory.load_his_data import load_index_joinquant
from finfactory.fintools.utils_chn import merge_minute_candle
from finfactory.finplot.plot_candle import plot_candle
import finfactory.fintools.fintools as fintools

# %%
df1 = load_index_joinquant('000300.XSHG', '1min')
# df5 = merge_minute_candle(df1, 5, ['volume', 'money'])
# df15 = merge_minute_candle(df1, 15, ['volume', 'money'])
df30 = merge_minute_candle(df1, 30, ['volume', 'money'])
# Out:
# function `merge_minute_candle` run time: 24.741746s.

# %%
# print('df1.shape', df1.shape)
# print('df5.shape', df5.shape)
# print('df15.shape', df15.shape)
print('df30.shape', df30.shape)
# Out:
# df30.shape (33592, 7)

# %%
df = df30.set_index('time')

# %%
df['ma_slow'] = df['close'].rolling(30).mean()
df['ma_fast'] = df['close'].rolling(15).mean()
df['f'] = df['ma_fast'] / df['ma_slow'] - 1

df.tail()
# Out:
#                           open      close       high        low        volume  \
# time
# 2022-07-15 11:30:00  4339.1115  4320.1122  4339.1133  4310.1823  1.230662e+09
# 2022-07-15 13:30:00  4321.0402  4299.1139  4321.1110  4296.8147  1.303241e+09
# 2022-07-15 14:00:00  4299.0944  4289.7812  4299.0944  4281.7630  1.340303e+09
# 2022-07-15 14:30:00  4290.0818  4278.2863  4290.0818  4275.3241  1.301692e+09
# 2022-07-15 15:00:00  4278.5297  4248.5273  4285.5724  4248.5273  2.469375e+09
#
#                             money      ma_slow      ma_fast         f
# time
# 2022-07-15 11:30:00  2.446889e+10  4326.645780  4326.752893  0.000025
# 2022-07-15 13:30:00  2.806646e+10  4325.048577  4324.847820 -0.000046
# 2022-07-15 14:00:00  2.679714e+10  4322.887283  4323.186567  0.000069
# 2022-07-15 14:30:00  2.504382e+10  4320.583160  4320.308320 -0.000064
# 2022-07-15 15:00:00  4.556011e+10  4317.330737  4315.782807 -0.000359

# %%
# for k in range(1, 101):
#     print(k, fintools.cal_ic(df, 'f', lag=k))

# %%
f_up = df['f'].quantile(0.95)
f_low = df['f'].quantile(0.05)
f_up, f_low = 0.01, -0.01
print(f_up, f_low)
# Out:
# 0.01 -0.01

# %%
# df['turn'] = fintools.get_turn_point(df['f'])
df['turn'] = fintools.get_limit_turn_point(df['f'], f_up, f_low)
df['bbw'] = fintools.bbw(df)

# %%
N = 3000
plot_series(df.iloc[-N:, :],
            cols_styl_up_left={
                'close': ('-k', None),
#                 'ma_fast': ('-r', None),
#                 'ma_slow': ('-y', None)
            },
            cols_styl_up_right={
                'f': ('-b', None),
#                 'bbw': ('-g', None)
            },
            cols_to_label_info={
                'f': [['turn', (-1, 1), ('r^', 'gv'), ('low', 'high')]],
                'close': [['turn', (-1, 1), ('r^', 'gv'), ('low', 'high')]]
            },
            xparls_info={'f': [(0,), (f_up,), (f_low,)]},
            n_xticks=6)
